# %%
from surrealdb import Surreal
db = Surreal('wss://test-prod-insta-06amo5vohhuqn9u9qa1lbl9rcg.aws-use1.surreal.cloud')
db.signin({"username": "root", "password": "rootrm"})
db.use("partyscene", "partyscene")
result = db.create("test", {"email": "test@example.com", "password": "testpass"})
print(result)
# Out:
# {'email': 'test@example.com', 'id': RecordID(table_name=test, record_id=jw6kol60t2bw2b997z5w), 'password': 'testpass'}
