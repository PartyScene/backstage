# %%
from surrealdb import Surreal
from pprint import pprint
from redis import Redis
import typing

with Surreal('wss://test-prod-insta-06amo5vohhuqn9u9qa1lbl9rcg.aws-use1.surreal.cloud') as db:
    db.signin({'username': 'root', 'password': 'rootrm'})
    db.use('partyscene', 'partyscene')
    s = db.query("SELECT * FROM events")
    print(s)
    db.query("DELETE FROM users; DELETE FROM events;")
# Out:
# [{'categories': ['beach'], 'created_at': datetime.datetime(2025, 4, 25, 19, 3, 45, 484231), 'creator': RecordID(table_name=users, record_id=test), 'degree_of_freedom': 1, 'description': 'Station suggest manager memory. Strong short decade focus again. Many I bed away.\nWhose message air in tell. Sound begin case remember. Five true simply ago free enough billion.', 'host': RecordID(table_name=users, record_id=test), 'id': RecordID(table_name=events, record_id=test), 'is_private': False, 'location': {'address': '7950 Matthew Prairie Apt. 195\nMorenoland, CA 12591', 'coordinates': {'coordinates': [-45.620776], 'type': 'Point'}}, 'metadata': {}, 'price': '11', 'start_time': '2025-04-27T00:03:45.292083', 'status': 'cancelled', 'time': datetime.datetime(2025, 4, 26, 19, 3, 45, 292694), 'title': 'Front-line user-facing hub', 'types': ['image/jpeg'], 'updated_at': 'time::now()'}]

# %%
from surrealdb import Surreal
from pprint import pprint
from redis import Redis
import typing

with Surreal('wss://test-prod-insta-06amo5vohhuqn9u9qa1lbl9rcg.aws-use1.surreal.cloud') as db:
    db.signin({'username': 'root', 'password': 'rootrm'})
    db.use('partyscene', 'partyscene')
    s = db.query("SELECT * FROM events WHERE title")
    pprint(s)
    x = db.query("SELECT * FROM users WHERE username = $username", {'username': 'random'})
    y = db.query("SELECT * FROM users WHERE crypto::argon2::compare(hashed_email, $email)", {'email': 'dylee@tutamail.com'})
    pprint(x)
    pprint(y)
    
    if bool(x): print("X is True")
    if bool(s): print("S is also True")
    
    if x: print("Last X Check")
    
import logging
redis = Redis.from_url(
                'redis://default:R5WkzVGAM7ZavW9tnEv4iMVUPg7xOpnQ@redis-18628.c238.us-central1-2.gce.redns.redis-cloud.com:18628', decode_responses=True, encoding="utf-8"
            )


class Test:
    
    def __init__(self):
        self.bloom_filter = redis.bf()
    
    def _check_exists(self, param, type: typing.Literal['email', 'username']):
        """
        Check if a user with the given parameter exists in the database.

        Args:
            param: The parameter value to check
            type: The type of parameter ('email' or 'username')

        Returns:
            bool: True if the user exists, False otherwise
        """
        try:
            in_bloom = self.bloom_filter.exists(type, param)
            print("Bloom Match In Bloom %s" % in_bloom)
            if bool(in_bloom):
                return
            
            pprint(x)
            if bool(x):
                print(x.items())
                print("Bloom Match %s" % x)
            if y:
                print("Bloom Match %s" % y)
        except:
            ...

print(Test()._check_exists('dylee@tutamail.com', 'email') or Test()._check_exists('fakeName', 'username'))
# Out:
# [{'categories': ['beach'],
#   'created_at': datetime.datetime(2025, 4, 14, 15, 11, 20, 526826),
#   'degree_of_freedom': 1,
#   'description': 'Improve skill same rather. Region couple develop pretty. '
#                  'Wall let increase join perform young statement Congress.',
#   'embeddings': {},
#   'host': RecordID(table_name=users, record_id=test),
#   'id': RecordID(table_name=events, record_id=test),
#   'is_private': False,
#   'location': {'address': '2805 Jones Pike\nSouth Kellymouth, NH 75070',
#                'coordinates': {'coordinates': [-67.970493], 'type': 'Point'}},
#   'media': [RecordID(table_name=media, record_id=9mup0tdmd0a4gejxyu99)],
#   'metadata': {},
#   'price': '67',
#   'status': 'cancelled',
#   'time': datetime.datetime(2025, 4, 14, 15, 11, 20, 526919),
#   'title': 'Persistent didactic hardware'}]
# []
# [{'bio': 'Try else home page. Able water skill factor attack when article. '
#          'Lose star stop remain increase guy address dog.\n'
#          'Arm any city be record cup.\n'
#          'Skin enough against arrive student. Blue think anyone.',
#   'first_name': 'John',
#   'hashed_email': '$argon2id$v=19$m=19456,t=2,p=1$tFREXkghxszMAbcCjCpezQ$1/OCAS/IwAg2K9t0VZ0hX74Nal12VDX0ckBmEtut9SQ',
#   'hashed_password': '$argon2id$v=19$m=19456,t=2,p=1$jziBTikmUj+0oDLAb6DnPw$V8R8I71O8RQfkGadeRAqgvIkQ0YKn+PwaVqR0WV4/OQ',
#   'id': RecordID(table_name=users, record_id=02acbd2d29f8),
#   'last_name': 'Doe',
#   'sharedLoc': False,
#   'username': 'Anthony Warner'}]
# S is also True
# Bloom Match In Bloom 0
# []
# Bloom Match [{'bio': 'Try else home page. Able water skill factor attack when article. Lose star stop remain increase guy address dog.\nArm any city be record cup.\nSkin enough against arrive student. Blue think anyone.', 'first_name': 'John', 'hashed_email': '$argon2id$v=19$m=19456,t=2,p=1$tFREXkghxszMAbcCjCpezQ$1/OCAS/IwAg2K9t0VZ0hX74Nal12VDX0ckBmEtut9SQ', 'hashed_password': '$argon2id$v=19$m=19456,t=2,p=1$jziBTikmUj+0oDLAb6DnPw$V8R8I71O8RQfkGadeRAqgvIkQ0YKn+PwaVqR0WV4/OQ', 'id': RecordID(table_name=users, record_id=02acbd2d29f8), 'last_name': 'Doe', 'sharedLoc': False, 'username': 'Anthony Warner'}]
# Bloom Match In Bloom 0
# []
# Bloom Match [{'bio': 'Try else home page. Able water skill factor attack when article. Lose star stop remain increase guy address dog.\nArm any city be record cup.\nSkin enough against arrive student. Blue think anyone.', 'first_name': 'John', 'hashed_email': '$argon2id$v=19$m=19456,t=2,p=1$tFREXkghxszMAbcCjCpezQ$1/OCAS/IwAg2K9t0VZ0hX74Nal12VDX0ckBmEtut9SQ', 'hashed_password': '$argon2id$v=19$m=19456,t=2,p=1$jziBTikmUj+0oDLAb6DnPw$V8R8I71O8RQfkGadeRAqgvIkQ0YKn+PwaVqR0WV4/OQ', 'id': RecordID(table_name=users, record_id=02acbd2d29f8), 'last_name': 'Doe', 'sharedLoc': False, 'username': 'Anthony Warner'}]
# None

# %%
import redis

redis = redis.Redis.from_url(
                'redis://default:R5WkzVGAM7ZavW9tnEv4iMVUPg7xOpnQ@redis-18628.c238.us-central1-2.gce.redns.redis-cloud.com:18628', decode_responses=True, encoding="utf-8"
            )

bf = redis.bf()
# Set a random email
bf.add("emails", "x@x.com")
print(bf.exists("username", "dylee@il.com"))
# Out:
# 0

# %%
from cloudflare import Cloudflare
cf = Cloudflare(
    api_token='9ZCHYMii2PboxpcKjvW8O6O553s-rtdQmrs1KkPq'
)
accts = cf.accounts.list()
print(accts.result)
# Out:
# {'ip': '102.88.110.44', 'network': '102.88.96.0/20', 'version': 'IPv4', 'city': 'Lagos', 'region': 'Lagos', 'region_code': 'LA', 'country': 'NG', 'country_name': 'Nigeria', 'country_code': 'NG', 'country_code_iso3': 'NGA', 'country_capital': 'Abuja', 'country_tld': '.ng', 'continent_code': 'AF', 'in_eu': False, 'postal': None, 'latitude': 6.4474, 'longitude': 3.3903, 'timezone': 'Africa/Lagos', 'utc_offset': '+0100', 'country_calling_code': '+234', 'currency': 'NGN', 'currency_name': 'Naira', 'languages': 'en-NG,ha,yo,ig,ff', 'country_area': 923768.0, 'country_population': 195874740, 'asn': 'AS29465', 'org': 'MTN NIGERIA Communication limited'}
