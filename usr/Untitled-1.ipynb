# %%
from stripe import StripeClient
import stripe

stripe.api_key = "x"
account = stripe.Account.retrieve("x")
print(account)
# Out:
# {
#   "business_profile": {
#     "annual_revenue": null,
#     "estimated_worker_count": null,
#     "mcc": "7922",
#     "minority_owned_business_designation": null,
#     "name": "Discords",
#     "support_address": null,
#     "support_email": null,
#     "support_phone": null,
#     "support_url": null,
#     "url": "www.partyscene.app"
#   },
#   "business_type": "individual",
#   "capabilities": {
#     "card_payments": "inactive",
#     "transfers": "inactive"
#   },
#   "charges_enabled": false,
#   "company": {
#     "name": null
#   },
#   "controller": {
#     "fees": {
#       "payer": "application_express"
#     },
#     "is_controller": true,
#     "losses": {
#       "payments": "application"
#     },
#     "requirement_collection": "stripe",
#     "stripe_dashboard": {
#       "type": "express"
#     },
#     "type": "application"
#   },
#   "country": "US",
#   "created": 1757747654,
#   "default_currency": "usd",
#   "details_submitted": true,
# ...

# %%
from surrealdb import Surreal, RecordID
from pprint import pprint
from redis import Redis
import typing
from surrealdb.data.types import geometry

with Surreal('ws://35.209.221.56:8000') as db:
    db.signin({'username': 'root', 'password': 'rootrm'})
    db.use('partyscene', 'partyscene')
    event=db.select(RecordID("events", "809fd5a80993"))
    x = db.query(
                "UPDATE ONLY type::thing('users', $record_id) MERGE $content RETURN AFTER;",
                {"content": {"stripe_account_kyc_status": True}, "record_id": "ff1b3de286e6"},
            )
    # db.query("CREATE users:test SET name = 'test', age = 1")
    # s = db.query(
    #             "RETURN fn::create_relationship($origin, $target, $status);",
    #             {
    #                 "origin": RecordID("users", "test"),
    #                 "target": RecordID("users", "test2"),
    #                 "status": {}.get("status", "pending"),
    #             },
    
    #         )
    # x = db.query("CREATE something SET resource = $resource", {"resource": "users:test"})
    # s = db.query("SELECT <-comments.* AS comments FROM ONLY posts:g7dl6qmmt0b1s4k7of6j")
    # print(s)
    # print(s['relationship'])
    # x = db.query(
    #                     "SELECT filename FROM media WHERE status = 'pending'",
    #                 )
    # v = db.delete(RecordID("events", "test"))
    # y = db.query("RELATE $user -> attends -> $event SET status = $status;", 
    #              {
    #                  "user": RecordID("users", "test"),
    #                  "event": RecordID("events", "test"),
    #                  "status": "going"
    #              })
    # # s = db.query("DELETE FROM users; DELETE FROM friends; DELETE FROM events; DELETE FROM posts; DELETE FROM comments;")
    # # x = db.query("CREATE events:test SET location = $coord", {"coord": geometry.GeometryPoint.parse_coordinates([12.9999, 22.990])})
    # print(x)
    # print(v)
    print(x)
    # db.query("REMOVE db partyscene;")
# Out:
# {'auth_provider': 'password', 'avatar': '', 'bio': '', 'email': 'kukuakpos@gmail.com', 'first_name': 'Oyin', 'hashed_email': '$argon2id$v=19$m=19456,t=2,p=1$yOuM2zEe8/VxaQ88Mhpzlg$3sSrM42pTD3G4kct0bphJf8sgaOGP2KvLHgCfj6fHOA', 'hashed_password': '$argon2id$v=19$m=19456,t=2,p=1$RcRSS9OtkU/F0n5SibIyVw$0QaWUWw+zHA2srMc3a8vbJaYfgUluR90b+sjyGkllvc', 'id': RecordID(table_name=users, record_id=ff1b3de286e6), 'kyc_payment_status': False, 'kyc_status': False, 'last_name': 'Doubra', 'password': '08168084478', 'sharedLoc': False, 'stripe_account_id': '', 'stripe_account_kyc_status': True, 'updated_at': datetime.datetime(2025, 9, 15, 0, 0, 56, 332637), 'username': 'dylee'}

# %%
from surrealdb import Surreal
from pprint import pprint
from redis import Redis
import typing

with Surreal('wss://test-prod-insta-06amo5vohhuqn9u9qa1lbl9rcg.aws-use1.surreal.cloud') as db:
    db.signin({'username': 'root', 'password': 'rootrm'})
    db.use('partyscene', 'partyscene')
    s = db.query("SELECT * FROM events WHERE title")
    pprint(s)
    x = db.query("SELECT * FROM users WHERE username = $username", {'username': 'random'})
    y = db.query("SELECT * FROM users WHERE crypto::argon2::compare(hashed_email, $email)", {'email': 'dylee@tutamail.com'})
    pprint(x)
    pprint(y)
    
    if bool(x): print("X is True")
    if bool(s): print("S is also True")
    
    if x: print("Last X Check")
    
import logging
redis = Redis.from_url(
                's', decode_responses=True, encoding="utf-8"
            )


class Test:
    
    def __init__(self):
        self.bloom_filter = redis.bf()
    
    def _check_exists(self, param, type: typing.Literal['email', 'username']):
        """
        Check if a user with the given parameter exists in the database.

        Args:
            param: The parameter value to check
            type: The type of parameter ('email' or 'username')

        Returns:
            bool: True if the user exists, False otherwise
        """
        try:
            in_bloom = self.bloom_filter.exists(type, param)
            print("Bloom Match In Bloom %s" % in_bloom)
            if bool(in_bloom):
                return
            
            pprint(x)
            if bool(x):
                print(x.items())
                print("Bloom Match %s" % x)
            if y:
                print("Bloom Match %s" % y)
        except:
            ...

print(Test()._check_exists('dylee@tutamail.com', 'email') or Test()._check_exists('fakeName', 'username'))
# Out:
# []
# []
# []
# Bloom Match In Bloom 0
# []
# Bloom Match In Bloom 0
# []
# None

# %%
import redis

redis = redis.Redis.from_url(
                'redis://default:R5WkzVGAM7ZavW9tnEv4iMVUPg7xOpnQ@redis-18628.c238.us-central1-2.gce.redns.redis-cloud.com:18628', decode_responses=True, encoding="utf-8"
            )

print(redis.hgetall())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       1 import redis
#       3 redis = redis.Redis.from_url(
#       4                 'redis://default:R5WkzVGAM7ZavW9tnEv4iMVUPg7xOpnQ@redis-18628.c238.us-central1-2.gce.redns.redis-cloud.com:18628', decode_responses=True, encoding="utf-8"
#       5             )
# ----> 7 print(redis.hgetall())
#
# TypeError: HashCommands.hgetall() missing 1 required positional argument: 'name'

# %%
from cloudflare import Cloudflare
cf = Cloudflare(
    api_token='9ZCHYMii2PboxpcKjvW8O6O553s-rtdQmrs1KkPq'
)
accts = cf.accounts.list()
print(accts.result)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[6], line 5
#       1 from cloudflare import Cloudflare
#       2 cf = Cloudflare(
#       3     api_token='9ZCHYMii2PboxpcKjvW8O6O553s-rtdQmrs1KkPq'
#       4 )
# ----> 5 accts = cf.accounts.list()
#       6 print(accts.result)
#
# File ~/Documents/projects/partyscene/backstage/venv/lib/python3.12/site-packages/cloudflare/resources/accounts/accounts.py:253, in AccountsResource.list(self, direction, name, page, per_page, extra_headers, extra_query, extra_body, timeout)
#     219 def list(
#     220     self,
#     221     *,
#    (...)    231     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     232 ) -> SyncV4PagePaginationArray[Account]:
#     233     """
#     234     List all accounts you have ownership or verified access to.
#     235
# ...

# %%
from decimal import Decimal
from surrealdb.data.types import geometry
x, y = Decimal('0.1'), Decimal('0.290')

print(geometry.GeometryPoint.parse_coordinates([x, y]))
# Out:
# GeometryPoint(longitude=0.1, latitude=0.290)
