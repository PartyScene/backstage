# %%
from surrealdb import Surreal
from pprint import pprint
import orjson as json

with Surreal('wss://test-prod-insta-06amo5vohhuqn9u9qa1lbl9rcg.aws-use1.surreal.cloud') as db:
    db.signin({'username': 'root', 'password': 'rootrm'})
    db.use('partyscene', 'partyscene')
    db.query("RETURN <number> 'ok';")
    x = db.query("""
                 SELECT * FROM users WHERE crypto::argon2::compare(hashed_email, $email);
                 """, {'email': "dylee@tutamail.comk"})
    pprint(x)
# Out:
# []

# %%
# Ensure pika is installed in your Jupyter environment
# !pip install pika

import pika
import sys # Still useful for printing status

# --- Configuration (Set these variables directly) ---
# RABBITMQ_HOST = '34.60.70.88' # e.g., 'localhost', 
# RABBITMQ_PORT = 5672
# RABBITMQ_VHOST = '/'
# RABBITMQ_USER = 'guest'      # e.g., 'guest' or your specific user
# RABBITMQ_PASSWORD = 'guest'  # e.g., 'guest' or your specific password
# # --- End Configuration ---


# credentials = None
# if RABBITMQ_USER and RABBITMQ_PASSWORD:
#     credentials = pika.PlainCredentials(RABBITMQ_USER, RABBITMQ_PASSWORD)

# params = pika.ConnectionParameters(
#     host=RABBITMQ_HOST,
#     port=RABBITMQ_PORT,
#     virtual_host=RABBITMQ_VHOST,
#     credentials=credentials,
#     heartbeat=10, # Short heartbeat for quicker failure detection
#     blocked_connection_timeout=10 # Timeout for connection attempt
# )

param = pika.URLParameters("amqp://guest:guest@34.132.240.38:5672/")

print(f"Attempting to connect to {param}...")


connection = pika.BlockingConnection(param)
# If the above line doesn't raise an exception, the connection is open
print(f"✅ Connection successful!")
connection.close() # Close the connection cleanly)

# You can add more code here to run after the connection test if needed
# Out:
# Attempting to connect to <URLParameters host=34.132.240.38 port=5672 virtual_host=/ ssl=False>...
# ✅ Connection successful!
